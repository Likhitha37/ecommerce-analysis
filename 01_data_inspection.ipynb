# %%
import pandas as pd
import numpy as np
import os

data_path = r"C:\Users\likhi\OneDrive\Desktop\e commerce project\data\\"

print("Files found:")
for f in os.listdir(data_path):
    print(" ", f)
# Out:
# Files found:
#   olist_customers_dataset.csv
#   olist_geolocation_dataset.csv
#   olist_orders_dataset.csv
#   olist_order_items_dataset.csv
#   olist_order_payments_dataset.csv
#   olist_order_reviews_dataset.csv
#   olist_products_dataset.csv
#   olist_sellers_dataset.csv
#   product_category_name_translation.csv

# %%
orders       = pd.read_csv(data_path + "olist_orders_dataset.csv", encoding='utf-8', low_memory=False)
order_items  = pd.read_csv(data_path + "olist_order_items_dataset.csv", encoding='utf-8', low_memory=False)
customers    = pd.read_csv(data_path + "olist_customers_dataset.csv", encoding='utf-8', low_memory=False)
products     = pd.read_csv(data_path + "olist_products_dataset.csv", encoding='utf-8', low_memory=False)
sellers      = pd.read_csv(data_path + "olist_sellers_dataset.csv", encoding='utf-8', low_memory=False)
reviews      = pd.read_csv(data_path + "olist_order_reviews_dataset.csv", encoding='utf-8', low_memory=False)
payments     = pd.read_csv(data_path + "olist_order_payments_dataset.csv", encoding='utf-8', low_memory=False)
geolocation  = pd.read_csv(data_path + "olist_geolocation_dataset.csv", encoding='utf-8', low_memory=False)
category_translation = pd.read_csv(data_path + "product_category_name_translation.csv", encoding='utf-8', low_memory=False)

print("All 9 tables loaded successfully")
# Out:
# All 9 tables loaded successfully

# %%
def inspect_df(name, df):
    print(f"\n{'='*50}")
    print(f"TABLE: {name}")
    print(f"Rows: {df.shape[0]}  |  Columns: {df.shape[1]}")
    print(f"\nNull counts:")
    print(df.isnull().sum())
    print(f"\nSample:")
    display(df.head(3))

inspect_df("orders", orders)
inspect_df("order_items", order_items)
inspect_df("customers", customers)
inspect_df("products", products)
inspect_df("sellers", sellers)
inspect_df("reviews", reviews)
inspect_df("payments", payments)
inspect_df("category_translation", category_translation)
# Out:
# ...
# TABLE: orders
# Rows: 99441  |  Columns: 8
#
# Null counts:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64
#
# Sample:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
#
# ...

# %%
print("Orders unique order_ids:", orders['order_id'].nunique())
print("Items unique order_ids:", order_items['order_id'].nunique())
print("Reviews unique order_ids:", reviews['order_id'].nunique())

orphaned = order_items[~order_items['order_id'].isin(orders['order_id'])]
print(f"\nOrphaned item rows (no matching order): {len(orphaned)}")
# Out:
# Orders unique order_ids: 99441
# Items unique order_ids: 98666
# Reviews unique order_ids: 98673
#
# Orphaned item rows (no matching order): 0

# %% [markdown]
# ## Data Inspection Observations
#
# ### orders (99,441 rows)
# - 160 nulls in order_approved_at — likely cancelled orders
# - 2,965 nulls in order_delivered_customer_date — orders never delivered
# - All date columns are strings — will convert to datetime in cleaning
#
# ### products (32,951 rows)
# - 610 nulls in product_category_name — products with no category
# - Will join with category_translation for English names
#
# ### reviews (99,224 rows)
# - review_score has zero nulls — key column for analysis
# - 88% have no comment title, 59% no comment message — normal
#
# ### order_items, customers, payments, sellers
# - All completely clean, zero nulls
#
# ### Key things to fix in cleaning phase
# - Parse date columns to datetime
# - Engineer delivery_days, late_delivery, order_month columns
# - Join all tables into one master dataframe
# - Export clean_orders.csv to outputs folder
